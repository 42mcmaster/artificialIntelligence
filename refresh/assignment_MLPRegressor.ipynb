# %% [markdown]
# # MLP Regressor (Neural Network) Assignment
# ## Medina County Career Center — AI/ML
#
# **Your task:** Build an MLP Regressor from scratch AND compare it to Linear Regression.
#
# You've seen the full process in the Energy Efficiency class example. Same process — new dataset!
#
# ---
#
# ### Choose Your Dataset
#
# Pick ONE of these UCI datasets:
#
# | Dataset | UCI ID | What You Predict | Rows | Features | Notes |
# |---------|--------|------------------|------|----------|-------|
# | **Auto MPG** | 9 | Miles per gallon | 398 | 7 | Classic car data, some missing values |
# | **Wine Quality** | 186 | Quality score (1-10) | 4,898 | 12 | Red and white wine |
# | **Real Estate Valuation** | 477 | House price per unit area | 414 | 6 | Clean, no missing values |
# | **Abalone** | 1 | Age (rings) | 4,177 | 8 | Sea creature age prediction |
# | **Automobile** | 10 | Car price | 205 | 25 | More features, needs cleaning |
#
# ---
#
# ### The Steps
#
# 1. Install + import libraries
# 2. Load your dataset from UCI
# 3. Explore + clean
# 4. Train/test split
# 5. **SCALE the data** with StandardScaler
# 6. Build a Linear Regression model (baseline)
# 7. Build an MLP Regressor
# 8. Compare both models (R², MAE)
# 9. Visualize: side-by-side actual vs predicted
# 10. Try at least 2 different architectures

# %% [markdown]
# ## Step 1: Install + Import

# %%
# !pip install ucimlrepo -q

# %%
# Import your libraries
# You need everything from the regression assignment PLUS:
#   - StandardScaler (from sklearn.preprocessing)
#   - MLPRegressor (from sklearn.neural_network)
#   - warnings (optional, to suppress convergence warnings)

# %% [markdown]
# ## Step 2: Load Your Dataset

# %%
# Load your chosen dataset using fetch_ucirepo(id=___)
# Separate into X (features) and y (target)

# %% [markdown]
# ## Step 3: Explore + Clean

# %%
# Print shape, columns, missing values
# Handle any missing values (drop rows or fill)

# %%
# Create at least one visualization (heatmap, scatter plot, etc.)

# %% [markdown]
# ## Step 4: Train/Test Split

# %%
# Split 80/20

# %% [markdown]
# ## Step 5: Scale the Data
#
# Remember: fit the scaler on training data only, then transform both train AND test.

# %%
# Create StandardScaler
# fit_transform on X_train
# transform on X_test

# %% [markdown]
# ## Step 6: Build Linear Regression (Baseline)
#
# Always build a simple model first to compare against. Use UNSCALED data for Linear Regression.

# %%
# Build LinearRegression on UNSCALED data
# Calculate R² and MAE on test data

# %% [markdown]
# ## Step 7: Build MLP Regressor
#
# Use SCALED data. Pick an architecture to start — you'll experiment later.

# %%
# Build MLPRegressor on SCALED data
# Hint: MLPRegressor(hidden_layer_sizes=(64, 32), max_iter=500, random_state=42)
# Calculate R² and MAE on test data

# %% [markdown]
# ## Step 8: Compare Both Models

# %%
# Print a comparison table showing R² and MAE for both models
# Which one won?

# %% [markdown]
# ## Step 9: Visualize — Side by Side

# %%
# Create side-by-side actual vs predicted plots for both models
# Hint: use fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# %% [markdown]
# ## Step 10: Experiment with Architectures
#
# Try at least 2 different hidden_layer_sizes and compare. For example:
# - `(10,)` — small, 1 hidden layer
# - `(64, 32)` — medium, 2 hidden layers
# - `(128, 64, 32)` — large, 3 hidden layers

# %%
# Try different architectures and print a comparison table

# %% [markdown]
# ## Reflection (answer in this cell)
#
# 1. What dataset did you choose?
# 2. Did the neural network beat Linear Regression? By how much?
# 3. Which architecture worked best? Why do you think that is?
# 4. Why do neural networks need scaled data but Linear Regression doesn't?
# 5. For this dataset, would you recommend using a neural network or linear regression in the real world? Why?
