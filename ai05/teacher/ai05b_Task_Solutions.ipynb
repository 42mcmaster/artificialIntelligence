# %% [markdown]
# # INSTRUCTOR SOLUTIONS
# **DO NOT DISTRIBUTE TO STUDENTS**

# %% [markdown]
# # ai05b Task: Build Random Forest Models
#
# ## Your Assignment:
#
# Train Random Forest models on NBA data and compare them to single decision trees.
#
# **Learning Outcomes:**
# - Train RandomForestClassifier models
# - Compare ensemble vs. single tree accuracy
# - Tune n_estimators parameter
# - Interpret feature importance
# - Evaluate models on test data (not training data!)
#
# **Dataset:** NBA games with win/loss predictions. Located at `nba_win_prediction.csv`

# %%
import pandas as pd                          # Work with DataFrames
import numpy as np                           # Numerical operations
from sklearn.ensemble import RandomForestClassifier  # Random Forest
from sklearn.tree import DecisionTreeClassifier      # Single tree (for comparison)
from sklearn.model_selection import train_test_split # Split train/test
from sklearn.metrics import accuracy_score, classification_report  # Evaluation
import matplotlib.pyplot as plt              # Plotting

print("✓ Libraries imported")

# %% [markdown]
# ## Part 1: Load Data & Prepare Features

# %% [markdown]
# ### Task 1.1: Load NBA Data
#
# Load `nba_win_prediction.csv` and explore it.
#
# **Requirements:**
# 1. Load the CSV into a DataFrame named `nbaData`
# 2. Print shape, columns, and first 5 rows
# 3. Check the baseline accuracy (what % of games has home_win=1?)
# 4. Verify there are no missing values

# %%
# Your code here

# %% [markdown]
# ### Task 1.2: Split Features and Target
#
# **Requirements:**
# 1. Define feature columns: ['pts_diff', 'reb_diff', 'ast_diff', 'fg_pct_diff', 'tov_diff', 'stl_diff']
# 2. Create X (features) by selecting those columns
# 3. Create y (target) from 'home_win' column
# 4. Print shapes to verify: X should be (n_games, 6), y should be (n_games,)

# %%
# Your code here

# %% [markdown]
# ### Task 1.3: Train-Test Split
#
# **Requirements:**
# 1. Split X and y into train (80%) and test (20%)
# 2. Use test_size=0.2 and random_state=42
# 3. Create variables: xTrain, xTest, yTrain, yTest
# 4. Print sizes and win rates for both sets

# %%
# Your code here

# %% [markdown]
# ## Part 2: Train Random Forest

# %% [markdown]
# ### Task 2.1: Create and Train Forest (100 trees)
#
# **Requirements:**
# 1. Create RandomForestClassifier with n_estimators=100 and random_state=42
# 2. Train on xTrain, yTrain
# 3. Make predictions on xTest
# 4. Store predictions in variable `forestPred`
# 5. Calculate accuracy and store in `forestAccuracy`

# %%
# Your code here

# %% [markdown]
# ### Task 2.2: Report Results
#
# **Requirements:**
# 1. Print accuracy
# 2. Compare to baseline (always predict home = 54%)
# 3. Print classification report
# 4. Print confusion matrix

# %%
# Your code here

# %% [markdown]
# ## Part 3: Feature Importance

# %% [markdown]
# ### Task 3.1: Extract and Display Feature Importance
#
# **Requirements:**
# 1. Get feature_importances_ from the trained forest
# 2. Create a DataFrame with columns: Feature, Importance
# 3. Sort by Importance (highest first)
# 4. Display as a table

# %%
# Your code here

# %% [markdown]
# ### Task 3.2: Visualize Feature Importance
#
# **Requirements:**
# 1. Create a horizontal bar chart
# 2. X-axis = Importance, Y-axis = Feature
# 3. Color bars in steelblue
# 4. Add title and labels

# %%
# Your code here

# %% [markdown]
# ## Part 4: Comparison — Single Tree vs. Forest

# %% [markdown]
# ### Task 4.1: Train Single Decision Tree
#
# **Requirements:**
# 1. Create DecisionTreeClassifier with random_state=42 (no n_estimators!)
# 2. Train on xTrain, yTrain
# 3. Make predictions on xTest
# 4. Calculate accuracy and store in `treeAccuracy`

# %%
# Your code here

# %% [markdown]
# ### Task 4.2: Compare Results
#
# **Requirements:**
# 1. Create a comparison table showing:
#    - Single Tree accuracy
#    - Random Forest (100 trees) accuracy
#    - Baseline accuracy (54%)
# 2. Calculate improvement: (forestAccuracy - treeAccuracy)
# 3. Show which model is better

# %%
# Your code here

# %% [markdown]
# ## Part 5: Tuning — Does More Trees = Better?

# %% [markdown]
# ### Task 5.1: Train Forests with Different Tree Counts
#
# **Requirements:**
# 1. Test n_estimators values: [1, 5, 10, 25, 50, 100, 200]
# 2. For each, train a forest and measure accuracy on test data
# 3. Store results in lists: `treeCounts` and `accuracies`
# 4. Print results in a table format

# %%
# Your code here

# %% [markdown]
# ### Task 5.2: Visualize the Effect
#
# **Requirements:**
# 1. Create a line plot: x-axis = n_estimators, y-axis = accuracy
# 2. Add a horizontal line for baseline (54%)
# 3. Add a vertical line at n_estimators=100
# 4. Use log scale for x-axis
# 5. Add title and labels

# %%
# Your code here

# %% [markdown]
# ## Reflection Questions
#
# 1. **Random Forest vs. Single Tree:** Which was more accurate? Why?
# 2. **Feature Importance:** Which stat is MOST predictive of home wins? Why might that be?
# 3. **Tuning:** Did accuracy improve with more trees? At what point did it plateau?
# 4. **Real-World:** Would 62-66% accuracy be good enough to use this model for betting? Why or why not?
# 5. **Ensemble Learning:** Why does majority voting from diverse trees beat a single expert?

# %%
# Write your reflection answers here as comments
# Question 1:
# Question 2:
# Question 3:
# Question 4:
# Question 5:
