# %% [markdown]
# # ai05 DIY Task: Combine APIs + Random Forest
#
# ## Your Challenge: Build a Complete ML Pipeline
#
# Choose ONE of these options:
#
# ### Option A: Fetch API Data + Analyze with ML
# 1. Fetch weather data for a city using Open-Meteo
# 2. Fetch earthquake data using USGS
# 3. Combine data and train a model (Random Forest or single tree)
# 4. Make predictions and interpret results
#
# ### Option B: Build Random Forest on New Dataset
# 1. Find a CSV dataset (weather, sports, finance, etc.)
# 2. Train a Random Forest on this NEW data
# 3. Compare to single tree baseline
# 4. Extract and interpret feature importance
# 5. Experiment with tuning (n_estimators, max_depth, etc.)
#
# ### Option C: Build Your Own API + ML Project
# 1. Use an API you find interesting (weather, crypto, sports, etc.)
# 2. Fetch at least 100 samples of data
# 3. Engineer features from the data
# 4. Train a Random Forest to predict something
# 5. Report accuracy, feature importance, and insights
#
# **Requirements (all options):**
# - Heavy code comments (every line!)
# - camelCase variable names
# - Markdown explaining what you're doing
# - Test your code for errors
# - Write a conclusion summarizing your findings

# %%
import pandas as pd                          # DataFrames
import numpy as np                           # Numerical
import requests                              # APIs
from sklearn.ensemble import RandomForestClassifier  # Random Forest
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt              # Plotting
import warnings
warnings.filterwarnings('ignore')

print("✓ Libraries imported")

# %% [markdown]
# ## Your Project Title
#
# Write the title and description of YOUR project here.
#
# **What question are you trying to answer?**

# %%
# Write your project description here

# %% [markdown]
# ## Step 1: Data Collection
#
# Fetch data from an API OR load from a CSV file.

# %%
# Your code here

# %% [markdown]
# ## Step 2: Data Exploration
#
# Understand your data:
# - Shape
# - Data types
# - Missing values
# - Summary statistics

# %%
# Your code here

# %% [markdown]
# ## Step 3: Prepare Features
#
# Define X (features) and y (target).

# %%
# Your code here

# %% [markdown]
# ## Step 4: Train-Test Split
#
# Split into 80% train, 20% test.

# %%
# Your code here

# %% [markdown]
# ## Step 5: Train Random Forest
#
# Build and evaluate your forest.

# %%
# Your code here

# %% [markdown]
# ## Step 6: Feature Importance
#
# Which features matter most?

# %%
# Your code here

# %% [markdown]
# ## Step 7: Comparison (Optional)
#
# Compare to single tree or baseline.

# %%
# Your code here

# %% [markdown]
# ## Conclusion
#
# Write a paragraph (3-5 sentences) summarizing:
# 1. What you tried to predict/analyze
# 2. What your model accuracy was
# 3. Which features were most important
# 4. What you learned
# 5. What you'd do differently next time

# %%
# Your conclusion here
