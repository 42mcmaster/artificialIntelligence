# %% [markdown]
# # ai05a Task: Build API Queries & Fetch Real Data
#
# ## Your Assignment:
#
# Use the `requests` library to fetch real-world data from FREE APIs. No API key required!
#
# **Learning Outcomes:**
# - Build correct API URLs
# - Parse JSON responses
# - Convert API data into DataFrames
# - Handle API errors gracefully
#
# **Note:** Test all URLs in your browser first before writing Python code.

# %% [markdown]
# ## Part 1: Weather Data from Open-Meteo API

# %%
import requests                              # Fetch data from the internet
import pandas as pd                          # Work with DataFrames

print("✓ Libraries imported")

# %% [markdown]
# ### Task 1.1: Fetch Weather Forecast for Medina, OH
#
# **Requirements:**
# 1. Use Open-Meteo API: `https://api.open-meteo.com/v1/forecast`
# 2. Parameters: latitude=41.14, longitude=-81.86, daily=["temperature_2m_max", "precipitation_sum"]
# 3. Store response JSON in variable `weatherData`
# 4. Extract the daily data (temperature_2m_max, precipitation_sum, time)
# 5. Create a DataFrame named `weatherDf` with columns: date, temp_max, precipitation
#
# **Hint:** Test this URL in your browser first:
# ```
# https://api.open-meteo.com/v1/forecast?latitude=41.14&longitude=-81.86&daily=temperature_2m_max,precipitation_sum
# ```

# %%
# Your code here

# %% [markdown]
# ### Task 1.2: Display Results
#
# Show the weather forecast DataFrame. Calculate and print:
# - Average temperature
# - Days with precipitation > 0
# - Max temperature

# %%
# Your code here

# %% [markdown]
# ## Part 2: Earthquake Data from USGS API

# %% [markdown]
# ### Task 2.1: Fetch Recent Earthquakes (Magnitude 5.5+)
#
# **Requirements:**
# 1. Use USGS API: `https://earthquake.usgs.gov/fdsnws/event/1/query`
# 2. Parameters: format="geojson", minmagnitude=5.5, limit=20
# 3. Extract features from GeoJSON
# 4. Create a DataFrame named `eqDf` with columns: magnitude, place, latitude, longitude, depth_km
#
# **Hint:** GeoJSON structure:
# ```python
# data['features']  # List of earthquakes
# data['features'][0]['properties']['mag']  # Magnitude
# data['features'][0]['geometry']['coordinates']  # [lon, lat, depth]
# ```

# %%
# Your code here

# %% [markdown]
# ### Task 2.2: Analyze Earthquakes
#
# Display the earthquakes DataFrame and calculate:
# - Number of earthquakes found
# - Average magnitude
# - Deepest earthquake (max depth_km)
# - Shallowest earthquake (min depth_km)
# - Strongest earthquake (max magnitude)

# %%
# Your code here

# %% [markdown]
# ## Part 3: Book Search from Open Library API

# %% [markdown]
# ### Task 3.1: Search for Books
#
# **Requirements:**
# 1. Use Open Library API: `https://openlibrary.org/search.json`
# 2. Search for books with your favorite topic (try: "python", "machine learning", "data science")
# 3. Limit: 15 results
# 4. Create a DataFrame named `booksDf` with columns: title, author, first_publish_year, isbn (if available)
#
# **Hint:** Test this URL in your browser:
# ```
# https://openlibrary.org/search.json?title=python&limit=15
# ```
#
# Access authors like: `doc['author_name'][0]` (first author)

# %%
# Your code here

# %% [markdown]
# ### Task 3.2: Display Results
#
# Show the top 10 books in your search results. What's the oldest book? The newest?

# %%
# Your code here

# %% [markdown]
# ## Reflection Questions
#
# 1. **What was the hardest part of this task?** (URL building, JSON parsing, error handling, etc.)
# 2. **Which API was easiest to use?** Why?
# 3. **How could you use APIs in a real machine learning project?**
# 4. **What happens if you request data from an invalid endpoint?** Test it!

# %%
# Test an invalid API endpoint here
# Your code here
