# %% [markdown]
# # ai04 DIY Task: Discover NBA Insights with SQL
#
# **Applications of Artificial Intelligence**
# Medina County Career Center | Ryan McMaster, CTE Instructor
#
# ---
#
# ## Purpose
#
# Write your own SQL queries to discover interesting statistics and patterns in the NBA database.
#
# ## Challenge
#
# Write **5 original SQL queries** to answer questions YOU create about the NBA data.
#
# You may use:
# - SELECT, FROM, WHERE, ORDER BY, LIMIT (from ai04a)
# - GROUP BY, COUNT, SUM, AVG, MIN, MAX, HAVING (from ai04b)
# - Any combination of the above!
#
# ## Requirements
#
# Each query must:
# 1. **Have a clear question** (What are you trying to find?)
# 2. **Use proper SQL syntax** (SELECT → FROM → WHERE → GROUP BY → ORDER BY)
# 3. **Return meaningful results** (Results should answer your question)
# 4. **Have comments** explaining what each clause does
#
# ## Ideas for Queries
#
# ### Easy (SELECT, WHERE, ORDER BY, LIMIT)
# - Find all teams from a specific state
# - Find the top 10 highest-scoring individual games
# - Find teams founded in a specific decade
# - Find losses where teams scored 120+ points (should be rare!)
#
# ### Medium (GROUP BY, COUNT, AVG, HAVING)
# - Which team had the most wins in 2021-22?
# - Which team had the highest average scoring?
# - How many players averaged 10+ PPG per team?
# - Which teams averaged 110+ PPG across all games?
#
# ### Hard (Complex combinations)
# - For each team, calculate win percentage (wins / total games)
# - Find teams that won despite low scoring
# - Compare home vs away performance
# - Identify shooting efficiency leaders
#
# ---
#
# ## Setup

# %%
import pandas as pd
import sqlite3

nbaConnection = sqlite3.connect('nba_5seasons.db')
print("✅ Connected to NBA database")

# %% [markdown]
# ---
#
# ## Query 1: Your Question

# %% [markdown]
# **What do you want to find out?**
#
# Write your question here:
#
# *(Example: "Which teams had the best 3-point shooting percentage in 2021-22?")*

# %%
# Your SQL query here
# Include comments explaining each clause
# Example pattern:
# query = """
# SELECT column1, column2
# FROM table
# WHERE condition
# ORDER BY column
# """
# results = pd.read_sql(query, nbaConnection)
# display(results)

# %% [markdown]
# **What do the results tell you?**
#
# Write your analysis here.

# %% [markdown]
# ---
#
# ## Query 2: Your Question

# %% [markdown]
# **What do you want to find out?**

# %%
# Your SQL query here

# %% [markdown]
# **Analysis:**

# %% [markdown]
# ---
#
# ## Query 3: Your Question

# %% [markdown]
# **What do you want to find out?**

# %%
# Your SQL query here

# %% [markdown]
# **Analysis:**

# %% [markdown]
# ---
#
# ## Query 4: Your Question

# %% [markdown]
# **What do you want to find out?**

# %%
# Your SQL query here

# %% [markdown]
# **Analysis:**

# %% [markdown]
# ---
#
# ## Query 5: Your Question

# %% [markdown]
# **What do you want to find out?**

# %%
# Your SQL query here

# %% [markdown]
# **Analysis:**

# %% [markdown]
# ---
#
# ## Summary

# %% [markdown]
# **Most Interesting Finding:**
#
# Which of your 5 queries returned the most surprising or interesting result? Why?

# %% [markdown]
# **Your answer here**

# %% [markdown]
# ---
#
# ## Reflection

# %% [markdown]
# 1. How comfortable are you writing SQL queries now?
#    - Very comfortable
#    - Somewhat comfortable
#    - Need more practice
#
# 2. Which SQL concepts are still confusing?
#
# 3. How would you use these queries in a machine learning project?
#
# Write your answers below:

# %% [markdown]
# **Your reflection here**

# %% [markdown]
# ---
#
# ## Close Connection

# %%
nbaConnection.close()
print("✅ Database connection closed")

# %% [markdown]
# ---
#
# ## Congratulations!
#
# You've completed SQL for Machine Learning:
# - ✅ Learned SELECT, FROM, WHERE, ORDER BY, LIMIT
# - ✅ Learned GROUP BY, COUNT, AVG, SUM, MIN, MAX, HAVING
# - ✅ Practiced with guided tasks
# - ✅ Discovered your own insights
#
# **Next:** Use these SQL skills to build machine learning models!
