# %% [markdown]
# # ai04a Task: SQL Basics Practice
#
# **Applications of Artificial Intelligence**
# Medina County Career Center | Ryan McMaster, CTE Instructor
#
# ---
#
# ## Purpose
#
# Practice writing SQL SELECT, FROM, WHERE, ORDER BY, and LIMIT queries.
#
# ## Your Tasks
#
# Write SQL queries to answer the following questions about the NBA database.
# Each question should use the techniques from the walkthrough:
# - SELECT specific columns
# - FROM the correct table
# - WHERE to filter by conditions
# - ORDER BY to sort results
# - LIMIT to control output
#
# **Remember:** Text values need single quotes, numbers don't!

# %% [markdown]
# ---
#
# ## Setup

# %%
# Your code here
# Import pandas and sqlite3
# Connect to nba_5seasons.db
# Store connection in nbaConnection

# %% [markdown]
# ---
#
# ## Question 1: Find All Florida Teams
#
# Write a query to find all NBA teams located in Florida.
#
# **Columns to select:** full_name, city, state
#
# **Expected columns:** 2 teams (Heat, Magic)
#
# **Hint:** Use WHERE state = 'Florida'

# %%
# Your code here
# Write the SQL query
# Execute with pd.read_sql()
# Display the results

# %% [markdown]
# ---
#
# ## Question 2: Teams Founded in 1995
#
# Write a query to find all teams that were founded in exactly 1995.
#
# **Columns to select:** full_name, city, year_founded
#
# **Expected result:** 2 teams (Raptors, Grizzlies)
#
# **Hint:** Use WHERE year_founded = 1995

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Question 3: Top 5 Oldest Teams
#
# Write a query to find the 5 oldest NBA teams (by founding year).
#
# **Columns to select:** full_name, year_founded
#
# **Expected result:** 5 teams starting with Celtics (1946), Warriors (1946), Knicks (1946)
#
# **Hints:**
# - Use ORDER BY year_founded (ascending)
# - Use LIMIT 5
# - Remember: ORDER BY comes BEFORE LIMIT

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Question 4: Teams from New York or California
#
# Write a query to find all teams located in New York OR California.
#
# **Columns to select:** full_name, city, state
#
# **Expected result:** 6 teams (4 from CA, 2 from NY)
#
# **Hint:** Use OR to combine two conditions
#
# ```sql
# WHERE state = 'California' OR state = 'New York'
# ```

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Question 5: High-Scoring Players in 2021-22
#
# Write a query to find players who averaged 25+ points per game in the 2021-22 season.
#
# **Table:** player_season_stats
#
# **Columns to select:** player_id, season, pts, gp
#
# **Conditions:**
# - season = '2021-22'
# - pts >= 25
# - gp >= 40 (only players who played significant minutes)
#
# **Order:** by pts descending (highest first)
#
# **Limit:** 10
#
# **Hint:** Combine conditions with AND

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Question 6: High-Scoring Games in 2021-22
#
# Write a query to find the top 15 games where teams scored 130+ points in the 2021-22 season.
#
# **Table:** team_game_stats
#
# **Columns to select:** game_date, team_id, pts, wl
#
# **Conditions:**
# - season = '2021-22'
# - pts >= 130
#
# **Order:** by pts descending (highest first)
#
# **Limit:** 15
#
# **Hint:** team_game_stats has one row per team per game

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Question 7: Elite Shooters
#
# Write a query to find players with 40%+ 3-point shooting in 2021-22 (who also had enough playing time).
#
# **Table:** player_season_stats
#
# **Columns to select:** player_id, fg3_pct, pts, gp
#
# **Conditions:**
# - season = '2021-22'
# - fg3_pct >= 40 (40% or better)
# - gp >= 40 (meaningful playing time)
# - pts >= 10 (significant scoring role)
#
# **Order:** by fg3_pct descending
#
# **Limit:** 10
#
# **Hint:** Combine multiple conditions with AND

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Question 8: Teams Founded Between 1970 and 1990
#
# Write a query to find all teams founded between 1970 and 1990 (inclusive).
#
# **Columns to select:** full_name, year_founded, state
#
# **Hint:** Use BETWEEN for the year range
#
# ```sql
# WHERE year_founded BETWEEN 1970 AND 1990
# ```
#
# **Optional:** Sort by year_founded to see timeline

# %%
# Your code here

# %% [markdown]
# ---
#
# ## Close Connection

# %%
# Your code here
# Close the database connection

# %% [markdown]
# ---
#
# ## Reflection Questions
#
# After completing the queries, answer these reflection questions:
#
# 1. **Which table did you use most?** (teams, player_season_stats, or team_game_stats)
# 2. **What was the trickiest part** about writing SQL queries?
# 3. **Which query result surprised you?** Did any answers differ from what you expected?
# 4. **How is SQL different from pandas?** Which do you find easier?
#
# Write your answers below:

# %% [markdown]
# # Your reflection answers here

# %% [markdown]
# ---
#
# ## Assessment Checklist
#
# Before submitting, verify your work:
#
# - [ ] All 8 questions have working SQL queries
# - [ ] Each query follows the correct syntax (SELECT → FROM → WHERE → ORDER BY → LIMIT)
# - [ ] Text values use single quotes (not double quotes, not no quotes)
# - [ ] WHERE conditions use = (not ==)
# - [ ] Queries return results that make sense
# - [ ] Variable names use camelCase (e.g., floridaTeams, topScorers)
# - [ ] Code has comments explaining each query
# - [ ] Database connection is closed at the end
# - [ ] Reflection questions are answered
#
# ---
#
# ## Next Step
#
# Once you complete this task, move on to **ai04b_Task.ipynb** to learn about aggregation (GROUP BY, COUNT, SUM, AVG)!
