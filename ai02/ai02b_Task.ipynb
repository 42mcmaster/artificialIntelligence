# %% [markdown]
# # ai02b Task — Coding Decision Trees in Python
#
# ## Overview
#
# In this task, you will code two complete decision tree programs:
# 1. **Restaurant Recommender** (guided example)
# 2. **Custom Decision Tree** (your choice of topic)
#
# Each program should:
# - Get user input
# - Validate input (using `.lower()` and `.isdigit()`)
# - Use nested `if/elif/else` to make decisions
# - Print a clear recommendation
#
# ---

# %% [markdown]
# ## Task 1: Restaurant Recommender (Guided)
#
# ### Requirements
#
# Code a program that:
# 1. Asks: "Do you like spicy food?" (yes/no)
# 2. Asks: "Is your budget less than $15?" (yes/no)
# 3. Recommends a restaurant based on answers:
#    - Spicy + Budget ($15) → **Thai Bistro**
#    - Spicy + Expensive (>$15) → **Indian Palace**
#    - Not spicy + Budget → **Italian Kitchen**
#    - Not spicy + Expensive → **French Bistro**
#
# ### Checklist
#
# - [ ] Use `.lower()` to handle "YES" vs "yes" vs "Yes"
# - [ ] Validate input (check that user types yes/no)
# - [ ] Use nested `if/elif/else` (at least 2 levels deep)
# - [ ] Handle invalid input with error message
# - [ ] Clear output with restaurant recommendation
# - [ ] Heavy comments on every line
# - [ ] Use camelCase for variable names
#
# ### Your Code

# %%
# ==========================================
# Task 1: Restaurant Recommender
# ==========================================

# Your code here

# %% [markdown]
# ### Test Your Code
#
# Run your program with these test cases and verify outputs:
#
# | Test | Spicy? | Budget? | Expected Output |
# |------|--------|---------|------------------|
# | Test 1 | yes | yes | Thai Bistro |
# | Test 2 | yes | no | Indian Palace |
# | Test 3 | no | yes | Italian Kitchen |
# | Test 4 | no | no | French Bistro |
# | Test 5 | MAYBE | yes | Error message |
#
# **Your test results:**
# - Test 1 output: _______________
# - Test 2 output: _______________
# - Test 3 output: _______________
# - Test 4 output: _______________
# - Test 5 output: _______________

# %% [markdown]
# ---
#
# ## Task 2: Custom Decision Tree (Your Choice)
#
# ### Step 1: Choose Your Topic
#
# Pick ONE of these topics (or create your own):
# - Movie recommendations (action? violent?)
# - Workout recommendation (time available? experience level?)
# - What to eat for lunch (budget? time? diet restrictions?)
# - Game recommendation (prefer single player? strategy?)
# - Study strategy (subject? how much time?)
# - **Your own idea**: _______________
#
# ### Step 2: Design Your Tree
#
# Before you code, draw your tree:
#
# ```
# Your tree design:
#
#
#
#
# ```
#
# **Questions you'll ask:**
# 1. _______________
# 2. _______________
# 3. (Optional) _______________
#
# **Possible outcomes:**
# - Outcome 1: _______________
# - Outcome 2: _______________
# - Outcome 3: _______________
# - Outcome 4: _______________

# %% [markdown]
# ### Step 3: Code Your Tree
#
# Requirements:
# - [ ] **At least 2 questions** (create at least 4 different outcomes)
# - [ ] **Nested if/elif/else** structure
# - [ ] **Input validation** (using `.lower()` for text, `.isdigit()` for numbers)
# - [ ] **Error handling** (what if user enters invalid input?)
# - [ ] **Comments on every line** explaining the logic
# - [ ] **camelCase variable names** (e.g., `userChoice`, `budgetAmount`)
# - [ ] **Clear output** with final recommendation

# %%
# ==========================================
# Task 2: Custom Decision Tree
# Topic: _______________
# ==========================================

# Your code here

# %% [markdown]
# ### Step 4: Test and Debug
#
# Test your program with at least 5 different input combinations:
#
# | Test # | Input 1 | Input 2 | Output | Works? |
# |--------|---------|---------|--------|--------|
# | 1 | | | | Yes / No |
# | 2 | | | | Yes / No |
# | 3 | | | | Yes / No |
# | 4 | | | | Yes / No |
# | 5 (invalid) | | | | Yes / No |
#
# **Any bugs to fix?** (describe issues and how you fixed them)
#
# _______________

# %% [markdown]
# ---
#
# ## Reflection
#
# ### Question 1: Design Choices
#
# Why did you choose your topic? What makes it a good fit for a decision tree?
#
# Answer: _______________

# %% [markdown]
# ### Question 2: Nested If/Elif/Else
#
# Look at your custom tree code. How many levels of nesting do you have? (i.e., if inside another if inside another if?)
#
# Answer: I have ___ levels of nesting

# %% [markdown]
# ### Question 3: Input Validation
#
# What validation techniques did you use? (Check all that apply)
#
# - [ ] `.lower()` for text input
# - [ ] `.isdigit()` for number input
# - [ ] Checking if input is in a list of valid options
# - [ ] Error message for invalid input
# - [ ] Asking user to retry after invalid input
#
# Which was most important for your program? Why?
#
# Answer: _______________

# %% [markdown]
# ### Question 4: Improvements
#
# If you had more time, what would you add to your decision tree?
#
# Ideas:
# - More questions (expand the tree)
# - More outcomes (more detailed recommendations)
# - Better error handling (keep asking until valid input)
# - Use `and`/`or` for complex conditions
# - Store results in a file
#
# Your idea: _______________

# %% [markdown]
# ---
#
# ## Submission Checklist
#
# ### Task 1: Restaurant Recommender
# - [ ] Code is complete and runs without errors
# - [ ] All 5 test cases produce correct output
# - [ ] Input validation works (handles invalid input)
# - [ ] Code has comments explaining each section
# - [ ] Variable names are in camelCase
#
# ### Task 2: Custom Decision Tree
# - [ ] Topic chosen and design drawn
# - [ ] Code is complete and runs without errors
# - [ ] At least 2 questions asked
# - [ ] Nested if/elif/else structure used
# - [ ] Input validation implemented
# - [ ] Code has comments on every line
# - [ ] Variable names are in camelCase
# - [ ] All 5 test cases work (including invalid input test)
# - [ ] Reflection questions answered
#
# ### Overall
# - [ ] All code is clean and readable
# - [ ] No syntax errors
# - [ ] Both programs are submitted
