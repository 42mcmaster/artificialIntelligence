# %% [markdown]
# # ai02a Task — Decision Tree Concepts & Tracing
#
# ## Overview
#
# In this task, you will:
# 1. **Draw** decision trees for different scenarios
# 2. **Trace** through trees to find final outcomes
# 3. **Analyze** when decision trees are appropriate
#
# ---

# %% [markdown]
# ## Scenario 1: Video Game AI Behavior
#
# You're designing AI for an NPC (non-player character) in a video game.
#
# The NPC should:
# - **First decision**: Is the player within 10 meters?
#   - YES → **Second decision**: Does the NPC have health > 50%?
#     - YES → Chase the player
#     - NO → Run away
#   - NO → **Second decision**: Is there ammo in the area?
#     - YES → Search for ammo
#     - NO → Patrol
#
# ### Task 1a: Draw the Tree
#
# Draw this as an ASCII tree diagram or describe it as a flowchart:
#
# ```
# Your tree here (replace this):
#
#
#
#
# ```

# %% [markdown]
# ### Task 1b: Trace These Paths
#
# Using your tree, what happens in these situations?
#
# **Scenario A:** Player is 5 meters away, NPC has 60% health
# - Path: Player nearby? ___ | Health > 50%? ___
# - Outcome: _______________
#
# **Scenario B:** Player is 15 meters away, there is ammo nearby
# - Path: Player nearby? ___ | Ammo available? ___
# - Outcome: _______________
#
# **Scenario C:** Player is 8 meters away, NPC has 30% health
# - Path: Player nearby? ___ | Health > 50%? ___
# - Outcome: _______________

# %% [markdown]
# ### Task 1c: Identify Tree Parts
#
# In your video game tree:
# - **Root**: What is the first question?
# - **Total Nodes**: How many decision points are there?
# - **Total Leaves**: How many final outcomes are there?
# - **Longest Path**: What's the maximum number of questions to reach an outcome?

# %% [markdown]
# ---
#
# ## Scenario 2: College Major Selector
#
# A guidance counselor created a tree to suggest college majors:
#
# ```
#             Interested in working with people?
#             /                              \
#           YES                              NO
#           |                                |
#     Want high income?                Want to work on computers?
#     /              \                 /              \
#   YES              NO              YES              NO
#   |                |               |                |
# Law or     Social Work or    Computer     Environmental
# Medicine   Teaching          Science      Engineering
# ```
#
# ### Task 2a: Trace These Paths
#
# **Path 1:** Interested in people? YES | Want high income? YES
# - Recommended major: _______________
#
# **Path 2:** Interested in people? NO | Want computers? YES
# - Recommended major: _______________
#
# **Path 3:** Interested in people? YES | Want high income? NO
# - Recommended major: _______________
#
# **Path 4:** Interested in people? NO | Want computers? NO
# - Recommended major: _______________

# %% [markdown]
# ### Task 2b: Improve the Tree
#
# This tree only asks 2 questions. Think of a **third question** you could add to create more specific recommendations.
#
# Example: For students who like people AND want high income, you could ask:
# - "Do you like writing/communication?"
#   - YES → Lawyer
#   - NO → Doctor
#
# **Your addition:**
#
# For the branch: _______________
#
# Add question: _______________
#
# Outcomes:
# - YES → _______________
# - NO → _______________

# %% [markdown]
# ### Task 2c: Draw the Full Expanded Tree
#
# Add your new question to the tree and redraw it below:
#
# ```
# Your expanded tree here:
#
#
#
#
# ```

# %% [markdown]
# ---
#
# ## Scenario 3: Email Spam Filter
#
# Create your own decision tree for a **spam email filter**.
#
# ### Task 3a: Brainstorm Questions
#
# What yes/no questions could a spam filter ask to identify spam?
#
# Write at least 3 questions:
# 1. _______________
# 2. _______________
# 3. _______________

# %% [markdown]
# ### Task 3b: Design Your Tree
#
# Create a decision tree using at least 2 of your questions from 3a.
#
# Final outcomes should be:
# - **Legitimate** (safe email, deliver to inbox)
# - **Suspicious** (might be spam, move to spam folder)
# - **Definitely Spam** (block it)
#
# Draw your tree below:
#
# ```
# Your spam filter tree:
#
#
#
#
# ```

# %% [markdown]
# ### Task 3c: Test Your Tree
#
# Test your spam filter with these emails:
#
# **Email 1:** "Congratulations! You won $1 million! Click here to claim."
# - Questions asked: _______________
# - Classification: ___ Legitimate | ___ Suspicious | ___ Definitely Spam
#
# **Email 2:** "Project meeting rescheduled to 2pm Thursday. - Manager Sarah"
# - Questions asked: _______________
# - Classification: ___ Legitimate | ___ Suspicious | ___ Definitely Spam
#
# **Email 3:** "Hi, click this link to verify your password urgently"
# - Questions asked: _______________
# - Classification: ___ Legitimate | ___ Suspicious | ___ Definitely Spam

# %% [markdown]
# ---
#
# ## Reflection Questions
#
# 1. **Why use decision trees?** In Scenario 1 (video game AI), why is a decision tree a good approach? What would make it NOT a good approach?
#
#    Answer: _______________________________________________
#
# 2. **Advantages:** What's the main advantage of the college major tree (Scenario 2)? Why is it better than just giving everyone a long list of majors?
#
#    Answer: _______________________________________________
#
# 3. **Limitations:** Can you think of a decision that would be HARD to represent as a tree? Why?
#
#    Answer: _______________________________________________

# %% [markdown]
# ---
#
# ## Submission Checklist
#
# - [ ] Completed Scenario 1: Video game AI tree (Task 1a, 1b, 1c)
# - [ ] Completed Scenario 2: College major selector (Task 2a, 2b, 2c)
# - [ ] Completed Scenario 3: Spam filter (Task 3a, 3b, 3c)
# - [ ] Answered reflection questions
# - [ ] All trees are clearly drawn or described
# - [ ] All traces are correctly labeled (yes/no paths)
# - [ ] Final outcomes are clearly stated
