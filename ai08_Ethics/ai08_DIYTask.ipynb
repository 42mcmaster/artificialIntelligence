# %% [markdown]
# # DIY Task: Independent AI Impact Analysis
# ## Student Version
#
# **Objective:** Choose a real-world AI application. Analyze it for bias risks, privacy concerns, and ethical implications. Propose safeguards.
#
# **This is an independent research and analysis task.**
#
# ---
#
# ## Part 1: Choose Your AI Application
#
# Pick ONE real-world AI system from this list, OR choose your own:
#
# **Examples:**
# - Recommendation algorithms (Netflix, Spotify, YouTube)
# - Facial recognition (phones, law enforcement, airports)
# - AI job application screening
# - Autonomous vehicles / self-driving cars
# - ChatGPT / Large language models
# - Medical diagnosis AI
# - Credit scoring algorithms
# - Social media content moderation
# - Predictive text / autocomplete
# - Deepfakes / synthetic media
# - AI tutoring systems
# - Hiring recommendation tools
#
# **My chosen AI application:** ________________

# %% [markdown]
# ---
#
# ## Part 2: How It Works (Research)
#
# **Q1. Describe the AI system: What is it? Who uses it? What problem does it solve?**
#
# Your answer:

# %% [markdown]
# **Q2. What data does it collect and process?**
#
# Your answer:

# %% [markdown]
# **Q3. How is the model trained? (What's in the training data?)**
#
# Your answer:

# %% [markdown]
# ---
#
# ## Part 3: Bias Analysis
#
# **Q4. Could this AI system have bias? How?**
#
# Use this framework:
# - Training data: Is it representative? Could it contain historical discrimination?
# - Proxy variables: Could the model learn biased patterns from innocent features?
# - Groups affected: Which groups could be disadvantaged?
#
# Your answer:

# %% [markdown]
# **Q5. What are the consequences if this AI is biased?**
#
# Who is harmed? What's the real-world impact?
#
# Your answer:

# %% [markdown]
# **Q6. How would you test this AI for bias?**
#
# What metrics would you measure? How would you find unfairness?
#
# Your answer:

# %% [markdown]
# ---
#
# ## Part 4: Privacy Analysis
#
# **Q7. What personal data does this system handle?**
#
# Your answer:

# %% [markdown]
# **Q8. Which privacy laws apply?** (HIPAA, FERPA, GDPR, PCI, others?)
#
# Your answer:

# %% [markdown]
# **Q9. Are there privacy risks? (Data breaches, misuse, over-collection?)**
#
# Your answer:

# %% [markdown]
# **Q10. What safeguards are currently in place?**
#
# Your answer:

# %% [markdown]
# ---
#
# ## Part 5: Ethical Considerations
#
# **Q11. Apply the ethical framework:**
#
# **Fairness:** Does this AI treat all groups equally?
#
# Your answer:
#
# **Transparency:** Do users understand how the AI works and affects them?
#
# Your answer:
#
# **Accountability:** Who is responsible if the AI causes harm?
#
# Your answer:
#
# **Explainability:** Can humans understand why the AI made a specific decision?
#
# Your answer:

# %% [markdown]
# ---
#
# ## Part 6: Proposed Safeguards
#
# **Q12. What safeguards would you recommend to make this AI more ethical and fair?**
#
# **During development:**
# - How to collect unbiased data?
# - How to test for fairness?
# - Whose perspectives should be included?
#
# Your answer:

# %% [markdown]
# **Q13. During deployment:**
# - How to ensure transparency?
# - How to give users control?
# - How to monitor for problems?
#
# Your answer:

# %% [markdown]
# **Q14. Organizational/regulatory:**
# - What policies should govern this AI?
# - Should it be regulated? How?
# - Who should have oversight?
#
# Your answer:

# %% [markdown]
# ---
#
# ## Part 7: Reflection
#
# **Q15. Overall assessment:**
#
# Based on your analysis:
# - Should this AI exist?
# - Is it currently deployed responsibly?
# - What's the biggest ethical concern?
#
# Your answer:
