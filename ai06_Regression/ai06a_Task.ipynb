# %% [markdown]
# # Task 07a: Exploring Correlations
# ## Your Turn with Real Data
#
# **AI/ML Course | Medina County Career Center**
#
# In the walkthrough, you watched us calculate Pearson r for weather data. Now it's your turn.
#
# You'll use three datasets to calculate correlations, make scatter plots, and interpret the strength and direction of relationships.

# %% [markdown]
# ## Setup: Load Libraries

# %%
import pandas as pd                          # pandas = data tables
import numpy as np                           # numpy = math
import matplotlib.pyplot as plt              # matplotlib = charts
import seaborn as sns                        # seaborn = pretty charts

# Don't need ML libraries for this task — just statistics and visualization

print("Libraries loaded!")

# %% [markdown]
# ## Part 1: Height vs Shoe Size (Excel Warmup Review)
#
# You've already calculated Pearson r for this in Excel. Now do it in Python!

# %%
# Load the Excel warmup data
heightShoe = pd.read_excel('ai06_excel_height_shoe.xlsx')

print("First 10 rows:")
print(heightShoe.head(10))
print(f"\nShape: {heightShoe.shape}")

# %%
# YOUR TURN: Calculate Pearson r between height and shoe size
# Hint: Use .corr() method

# Your code here

# %%
# YOUR TURN: Calculate R² (remember: R² = r × r)

# Your code here

# %%
# YOUR TURN: Make a scatter plot with height on x-axis, shoe size on y-axis
# Add labels, title, and use alpha=0.5 for transparency

# Your code here

# %% [markdown]
# ### Interpretation
#
# **YOUR TURN: Fill in your answers**
#
# 1. Pearson r value: ________
#
# 2. R² value: ________  Interpretation: This means ______% of shoe size variation is explained by height.
#
# 3. Does the scatter plot look like a straight line? (yes/no) ________
#
# 4. Is this a positive or negative correlation? ________ (What does that mean?)
#
# 5. How strong is the relationship? (very strong / strong / moderate / weak / very weak) ________

# %% [markdown]
# ## Part 2: Study Hours vs Test Score

# %%
# Load the Excel warmup data
studyScores = pd.read_excel('ai06_excel_study_scores.xlsx')

print("First 10 rows:")
print(studyScores.head(10))
print(f"\nShape: {studyScores.shape}")

# %%
# YOUR TURN: Calculate Pearson r between study hours and test score

# Your code here

# %%
# YOUR TURN: Calculate R²

# Your code here

# %%
# YOUR TURN: Make a scatter plot with study hours on x-axis, test score on y-axis

# Your code here

# %% [markdown]
# ### Interpretation
#
# **YOUR TURN: Fill in your answers**
#
# 1. Pearson r value: ________
#
# 2. R² value: ________  Interpretation: This means ______% of test score variation is explained by study hours.
#
# 3. Does the scatter plot look like a straight line? (yes/no) ________
#
# 4. Compared to height vs shoe size, is this relationship stronger or weaker? ________
#
# 5. Why do you think there's more scatter in this plot than the height/shoe size plot? (Hint: think about what other factors affect test scores)

# %% [markdown]
# ## Part 3: Ice Cream Sales vs Temperature

# %%
# Load the Excel warmup data
iceCreamTemp = pd.read_excel('ai06_excel_ice_cream_temp.xlsx')

print("First 10 rows:")
print(iceCreamTemp.head(10))
print(f"\nShape: {iceCreamTemp.shape}")

# %%
# YOUR TURN: Calculate Pearson r between temperature and ice cream sales

# Your code here

# %%
# YOUR TURN: Calculate R²

# Your code here

# %%
# YOUR TURN: Make a scatter plot with temperature on x-axis, sales on y-axis

# Your code here

# %% [markdown]
# ### Interpretation
#
# **YOUR TURN: Fill in your answers**
#
# 1. Pearson r value: ________
#
# 2. R² value: ________  Interpretation: This means ______% of ice cream sales variation is explained by temperature.
#
# 3. Is this relationship positive or negative? ________ (What does that mean in real-world terms?)
#
# 4. How strong is the relationship? (very strong / strong / moderate / weak / very weak) ________

# %% [markdown]
# ## Part 4: Rank All Three Relationships
#
# **YOUR TURN: Fill in the table below, ranking the three relationships from strongest to weakest:**
#
# | Rank | Relationship | Pearson r | R² | Strength |
# |------|-------------|-----------|-----|----------|
# | 1 (Strongest) | _____________ | _________ | _________ | _____________ |
# | 2 | _____________ | _________ | _________ | _____________ |
# | 3 (Weakest) | _____________ | _________ | _________ | _____________ |

# %% [markdown]
# ## Part 5: Challenge — Predict with Weather Data
#
# Using the full weather dataset, calculate the correlation between:
# - Temperature (temp_max) and two other variables of YOUR choice

# %%
# Load weather data
weather = pd.read_csv('medina_weather_2024.csv')
weather = weather.dropna()

print(f"Weather data shape: {weather.shape}")
print(f"\nAvailable columns: {list(weather.columns)}")

# %%
# YOUR TURN: Pick two variables and calculate their correlation with temp_max
# Your choices:
# Variable 1: ___________
# Variable 2: ___________

# Your code here

# %% [markdown]
# ### Interpretation
#
# **YOUR TURN: Fill in your answers**
#
# 1. Which two variables did you choose? _____________ and _____________
#
# 2. Pearson r values:
#    - temp_max & _____________ : r = _________
#    - temp_max & _____________ : r = _________
#
# 3. Which has the stronger relationship with temperature? _____________
#
# 4. Why do you think that is? (explain in 2-3 sentences)
