# %% [markdown]
# # ai06b Task: Evaluating AI Output
#
# **Name:** ___________________
# **Date:** ___________________
#
# In this task, you will practice evaluating AI-generated output using the five criteria: Validity, Relevance, Authenticity, Bias, and Hallucinations.

# %% [markdown]
# ## Part 1: Evaluate Sample Outputs
#
# For each output below, evaluate it using all five criteria. Rate each as Good (✓), Fair (~), or Poor (✗).

# %%
# SAMPLE OUTPUT 1: Biology Explanation
output1 = """Mitochondria are organelles in cells that produce energy in the form of ATP. 
They are called the 'powerhouse of the cell.' Mitochondria have their own DNA and 
can reproduce independently. They have a double membrane structure. When cells need 
energy, molecules are broken down inside mitochondria through a process called 
cellular respiration."""

print("SAMPLE OUTPUT 1: Mitochondria Explanation")
print("="*70)
print(output1)
print()
print()
print("Your Evaluation:")
print()
print("Validity: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Relevance: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Authenticity: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Bias: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Hallucinations: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Overall: GOOD / FAIR / POOR to use?")
print()
print("Why or why not?")
print()

# %%
# SAMPLE OUTPUT 2: Historical Information
output2 = """The Declaration of Independence was signed on July 4, 1776. 
It was written by Thomas Jefferson and a committee of five members including 
Benjamin Franklin and John Adams. The document declared the 13 American colonies' 
independence from British rule. It was signed in Philadelphia. A total of 56 delegates 
signed the Declaration. The signers risked their lives because the British could have 
executed them for treason."""

print("SAMPLE OUTPUT 2: Declaration of Independence")
print("="*70)
print(output2)
print()
print()
print("Your Evaluation:")
print()
print("Validity: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Relevance: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Authenticity: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Bias: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Hallucinations: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Overall: GOOD / FAIR / POOR to use?")
print()
print("Why or why not?")
print()

# %%
# SAMPLE OUTPUT 3: Career Advice
output3 = """Software engineering is the best career in tech because it pays the most. 
Most software engineers are men, which is just how the field naturally is. 
If you're good at math, you'll be a good engineer. Women are better at design roles 
because they have better taste. According to a 2020 study, 89% of engineers report 
satisfaction in their jobs. Graphic design is for people who aren't smart enough 
for engineering."""

print("SAMPLE OUTPUT 3: Career Advice")
print("="*70)
print(output3)
print()
print()
print("Your Evaluation:")
print()
print("Validity: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Relevance: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Authenticity: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Bias: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Hallucinations: [✓ / ~ / ✗]  Explanation: [Your analysis]")
print()
print("Overall: GOOD / FAIR / POOR to use?")
print()
print("Why or why not?")
print()

# %% [markdown]
# ## Part 2: Find the Problems
#
# Each output below has at least one problem. Identify and explain what's wrong.

# %%
# PROBLEM OUTPUT 1
problemOutput1 = """The average age of a cat is 15-20 years. Most cats are lazy and just sleep 
all day. Cats are not smart like dogs are. According to Dr. Helen Smith at MIT, 
recent research shows that 95% of cat owners regret getting a cat. This is why 
more people have dogs as pets."""

print("PROBLEM OUTPUT 1: About Cats")
print("="*70)
print(problemOutput1)
print()
print("Problems I found:")
print()
print("1. [Problem type and explanation]")
print()
print("2. [Problem type and explanation]")
print()
print("3. [Problem type and explanation]")
print()
print()
print("How would you fix this output?")
print()

# %%
# PROBLEM OUTPUT 2
problemOutput2 = """To make a peanut butter sandwich: First, grab two slices of bread 
and put them on the counter. Next, open the peanut butter jar and spread it on one slice. 
Then, do the same with jelly on the other slice. Push the two slices together. 
Cut diagonally for best results. Serve with a glass of milk and exactly 47 grapes."""

print("PROBLEM OUTPUT 2: Recipe Instructions")
print("="*70)
print(problemOutput2)
print()
print("Problems I found:")
print()
print("1. [Problem type and explanation]")
print()
print("2. [Problem type and explanation]")
print()
print()
print("How would you fix this output?")
print()

# %% [markdown]
# ## Part 3: Create Improved Versions
#
# Rewrite two of the problem outputs to fix the issues you identified.

# %%
# REWRITE PROBLEM OUTPUT 1 (Cats)
print("REWRITTEN OUTPUT 1 (Cats):")
print()
improvedOutput1 = """
[Your improved version here]
"""
print(improvedOutput1)
print()
print()

# REWRITE PROBLEM OUTPUT 2 (Sandwich)
print("REWRITTEN OUTPUT 2 (Sandwich):")
print()
improvedOutput2 = """
[Your improved version here]
"""
print(improvedOutput2)

# %% [markdown]
# ## Part 4: Reflect on Evaluation

# %%
print("REFLECTION QUESTIONS")
print()
print("1. Which evaluation criterion was easiest to spot? Why?")
print("   Answer: [Your response]")
print()
print()
print("2. Which criterion was hardest to identify? Why?")
print("   Answer: [Your response]")
print()
print()
print("3. In Sample Output 3 (careers), how many problems did you find?")
print("   Answer: [Number]")
print()
print()
print("4. Why is it dangerous to accept AI output without evaluation?")
print("   Answer: [Your response]")
print()
print()
print("5. What's one way you've learned to spot hallucinations?")
print("   Answer: [Your response]")
