# %% [markdown]
# # ai06 DIY Task: Real-World Prompt Engineering Challenge
#
# **Name:** ___________________
# **Date:** ___________________
#
# In this independent task, you will:
# 1. Choose a real problem you want AI to help with
# 2. Write and refine multiple prompts
# 3. Evaluate the AI's output
# 4. Document your entire process
#
# This is your chance to show mastery of prompt engineering!

# %% [markdown]
# ## Step 1: Choose Your Challenge
#
# Pick ONE of these real-world tasks (or propose your own):
#
# **Option A: Education**
# - Create practice questions for a subject you're learning
# - Explain a difficult concept for peers
# - Generate study guide outlines
#
# **Option B: Writing**
# - Draft an email or letter
# - Generate story ideas or plot outlines
# - Create character descriptions
#
# **Option C: Problem-Solving**
# - Get advice for a decision (school, career, personal)
# - Brainstorm solutions to a problem
# - Analyze cause-and-effect
#
# **Option D: Creative**
# - Generate ideas for a project
# - Create dialogue or scripts
# - Design worldbuilding for fiction
#
# **Option E: Your Own**
# - Describe a real task you want AI help with
# - Make sure it's appropriate and feasible

# %%
# STEP 1: Document your choice
print("STEP 1: CHOOSE YOUR CHALLENGE")
print("="*70)
print()
print("I choose: Option [A/B/C/D/E]")
print()
print("Specifically, I want AI to help with:")
print("[Describe your challenge in 2-3 sentences]")
print()
print()
print("Why I chose this:")
print("[Your reason]")

# %% [markdown]
# ## Step 2: Write Your First Prompt
#
# Create an initial prompt with all four elements: Context, Task, Format, Constraints.

# %%
# STEP 2: First Prompt
print("STEP 2: WRITE YOUR FIRST PROMPT")
print("="*70)
print()

print("First Attempt:")
print("-" * 70)
firstPrompt = """
[Write your complete first prompt here]
"""
print(firstPrompt)
print("-" * 70)
print()
print()
print("My reasoning for this prompt:")
print("[Explain your choices for Context, Task, Format, Constraints]")

# %% [markdown]
# ## Step 3: Get AI Output and Evaluate
#
# Simulate or actually get AI output. Then evaluate it carefully.

# %%
# STEP 3: AI Output and Evaluation
print("STEP 3: AI OUTPUT EVALUATION")
print("="*70)
print()

print("Simulated/Actual AI Response:")
print("-" * 70)
aiOutput = """
[Paste the AI output here, or write a realistic simulated output]
"""
print(aiOutput)
print("-" * 70)
print()

print("\nMy Evaluation:")
print()
print("Validity: [✓ / ~ / ✗]")
print("  Explanation: [Was it correct/logical/coherent?]")
print()
print("Relevance: [✓ / ~ / ✗]")
print("  Explanation: [Did it answer what I asked?]")
print()
print("Authenticity: [✓ / ~ / ✗]")
print("  Explanation: [Was it original or plagiarized?]")
print()
print("Bias: [✓ / ~ / ✗]")
print("  Explanation: [Did it show any stereotypes or unfairness?]")
print()
print("Hallucinations: [✓ / ~ / ✗]")
print("  Explanation: [Did it make up any false facts?]")
print()
print()
print("Overall Assessment:")
print("  [GOOD / FAIR / POOR]")
print()
print("Main strengths:")
print("  [What worked well?]")
print()
print("Main weaknesses:")
print("  [What needs improvement?]")

# %% [markdown]
# ## Step 4: Refine Your Prompt
#
# Based on evaluation, write an improved version.

# %%
# STEP 4: Refined Prompt
print("STEP 4: REFINED PROMPT")
print("="*70)
print()

print("What I changed:")
print("  1. [Specific change and why]")
print("  2. [Specific change and why]")
print("  3. [Specific change and why] (optional)")
print()

print("Refined Prompt:")
print("-" * 70)
refinedPrompt = """
[Write your improved prompt here]
"""
print(refinedPrompt)
print("-" * 70)
print()
print()
print("I expect this version to be better because:")
print("[Explain how your changes address the problems]")

# %% [markdown]
# ## Step 5: Get New Output and Compare
#
# Repeat the process with your refined prompt.

# %%
# STEP 5: New Output and Comparison
print("STEP 5: NEW OUTPUT & COMPARISON")
print("="*70)
print()

print("Second AI Response:")
print("-" * 70)
aiOutput2 = """
[Paste or simulate the output from refined prompt]
"""
print(aiOutput2)
print("-" * 70)
print()

print("\nQuick Evaluation of Second Output:")
print()
print("Validity: [✓ / ~ / ✗]")
print("Relevance: [✓ / ~ / ✗]")
print("Authenticity: [✓ / ~ / ✗]")
print("Bias: [✓ / ~ / ✗]")
print("Hallucinations: [✓ / ~ / ✗]")
print()
print()
print("Comparison: First vs. Second")
print()
print("What improved:")
print("  [What's better in the second version?]")
print()
print("What stayed the same or got worse:")
print("  [Any problems that persisted?]")
print()
print()
print("Is the second output ready to use?")
print("  YES / NEEDS MORE WORK / NO")
print()
print("Why?")
print("  [Explain your decision]")

# %% [markdown]
# ## Step 6: Reflection and Learning
#
# Summarize what you learned from this challenge.

# %%
# STEP 6: Reflection
print("STEP 6: REFLECTION")
print("="*70)
print()
print("Q1: What was the most surprising thing you learned?")
print("    [Your answer]")
print()
print()
print("Q2: Which prompting pattern did you use, and why?")
print("    [Your answer]")
print()
print()
print("Q3: If you had to do this over, what would you do differently?")
print("    [Your answer]")
print()
print()
print("Q4: How confident are you in your final AI output?")
print("    [1-10, with explanation]")
print()
print()
print("Q5: How will you use these prompt engineering skills in the future?")
print("    [Your answer]")
print()
print()
print("Overall, what was the hardest part of this task?")
print("    [Your answer]")

# %% [markdown]
# ## Submission Checklist
#
# Before you turn this in, check:
#
# - [ ] Step 1: Challenge clearly described
# - [ ] Step 2: First prompt has all 4 elements (Context, Task, Format, Constraints)
# - [ ] Step 3: AI output is realistic/actual, evaluation is thorough
# - [ ] Step 4: Refined prompt shows clear improvements
# - [ ] Step 5: Second output evaluated and compared to first
# - [ ] Step 6: Reflection answers are thoughtful and complete
# - [ ] All sections have your actual thinking/work (not generic answers)
# - [ ] Writing is clear and easy to follow
#
# Good luck! This is your chance to show you've mastered prompt engineering.
