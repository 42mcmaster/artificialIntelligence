# %% [markdown]
# # ai03a Task: Load, Explore, and Clean Data
#
# **Instructions:**
# - Complete each task below
# - Fill in missing code where you see `# Your code here`
# - Answer questions in markdown cells
# - Save and push to GitHub when finished
#
# **Goal**: Practice loading real-world data and preparing it for machine learning

# %% [markdown]
# ## Task 1: Import Required Libraries
#
# Import the libraries we'll need for data exploration and cleaning.

# %%
# Your code here
# Import pandas as pd
# Import matplotlib.pyplot as plt

print("✓ Libraries imported!")

# %% [markdown]
# ## Task 2: Load the Titanic Dataset
#
# Load the CSV file 'Titanic Dataset.csv' into a DataFrame called `titanicData`.

# %%
# Your code here
# Load 'Titanic Dataset.csv' using pd.read_csv()
# Store in variable: titanicData

# Verify it loaded
print(f"Dataset loaded: {titanicData.shape[0]} rows, {titanicData.shape[1]} columns")

# %% [markdown]
# ## Task 3: Explore the Data
#
# Use `.head()`, `.tail()`, `.info()`, and `.describe()` to understand the dataset.

# %%
# Task 3a: Show the first 5 rows
print("First 5 rows:")
# Your code here
# titanicData.head()

# %%
# Task 3b: Show the last 5 rows
print("\nLast 5 rows:")
# Your code here
# titanicData.tail()

# %%
# Task 3c: Get dataset information
print("\nDataset Information:")
# Your code here
# titanicData.info()

# %%
# Task 3d: Get statistical summary
print("\nStatistical Summary:")
# Your code here
# titanicData.describe()

# %% [markdown]
# ## Task 4: Answer Questions About the Data
#
# Based on the exploration above, answer these questions.

# %%
# Q1: How many total passengers are in the dataset?
totalPassengers = len(titanicData)  # Use len() on the DataFrame
print(f"Q1: Total passengers = {totalPassengers}")

# %%
# Q2: How many columns (features) does the dataset have?
totalColumns = len(titanicData.columns)  # Use len() on columns
print(f"Q2: Total columns = {totalColumns}")

# %%
# Q3: What is the average age of passengers?
# Your code here
# Hint: Use titanicData['age'].mean()
avgAge = None  # Replace None with your calculation
print(f"Q3: Average age = {avgAge}")

# %%
# Q4: How many passengers survived?
# Your code here
# Hint: survived column has 1=survived, 0=died. Use .sum()
survivorCount = None  # Replace with your code
print(f"Q4: Survivors = {survivorCount}")

# %%
# Q5: What percentage of passengers survived?
# Your code here
# Hint: (survivors / total) * 100
survivalRate = None  # Replace with your code
print(f"Q5: Survival rate = {survivalRate:.2f}%")

# %% [markdown]
# ## Task 5: Check for Missing Values
#
# Real-world data often has missing values. Let's find them!

# %%
# Show missing value counts for each column
print("Missing values per column:")
# Your code here
# Hint: Use titanicData.isnull().sum()

print(f"\nTotal missing values: {titanicData.isnull().sum().sum()}")

# %% [markdown]
# ## Task 6: Clean the Data
#
# Now let's prepare the data for machine learning.

# %%
# Step 1: Select only the columns we need
columnsNeeded = ['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked']
titanicData = titanicData[columnsNeeded]

print(f"✓ Selected {len(columnsNeeded)} columns")
print(f"Columns: {list(titanicData.columns)}")

# %%
# Step 2: Remove rows with missing values
rowsBefore = len(titanicData)
# Your code here
# Hint: Use titanicData.dropna()
titanicData = None  # Replace with cleaned data
rowsAfter = len(titanicData)

print(f"✓ Dropped missing values")
print(f"Rows before: {rowsBefore}")
print(f"Rows after: {rowsAfter}")
print(f"Rows removed: {rowsBefore - rowsAfter}")

# %%
# Step 3: Verify no missing values remain
print(f"\nMissing values after cleaning: {titanicData.isnull().sum().sum()}")
print("✓ Data is clean!")

# %%
# Step 4: Encode categorical columns (text to numbers)
print("\nBefore encoding:")
print(titanicData[['sex', 'embarked']].head())

# Your code here
# Hint: Use pd.get_dummies(titanicData, columns=['sex', 'embarked'], drop_first=True)
titanicData = None  # Replace with encoded data

print("\nAfter encoding:")
print(titanicData.head())
print(f"\nNew shape: {titanicData.shape}")
print(f"New columns: {list(titanicData.columns)}")

# %% [markdown]
# ## Task 7: Final Data Check
#
# Verify that your cleaned data is ready for machine learning.

# %%
# Verify all data is numeric
print("Data types:")
print(titanicData.dtypes)

print("\nData sample:")
print(titanicData.head())

print(f"\nFinal dataset shape: {titanicData.shape}")
print("✓ Data is ready for machine learning!")

# %% [markdown]
# ## Reflection Questions
#
# Answer these in your own words:

# %% [markdown]
# **Q1: Why is it important to explore data before cleaning it?**
#
# Your answer:

# %% [markdown]
# **Q2: What would happen if we trained a model on data with missing values?**
#
# Your answer:

# %% [markdown]
# **Q3: Why do we need to convert text (like 'male', 'female') to numbers?**
#
# Your answer:

# %% [markdown]
# **Q4: How many rows did we lose by removing missing values? Was it worth it?**
#
# Your answer:

# %% [markdown]
# ## Bonus Challenges (Optional)
#
# If you finish early, try these:
#
# **Challenge 1**: What is the average age of male vs female passengers?
# ```python
# # Hint: You need to use original data before encoding
# # Re-load the data and use groupby('sex')['age'].mean()
# ```
#
# **Challenge 2**: How many passengers were in each class (pclass)?
# ```python
# # Hint: Use .value_counts() on the pclass column
# ```
#
# **Challenge 3**: What was the survival rate for each passenger class?
# ```python
# # Hint: Use groupby('pclass')['survived'].mean()
# ```

# %%
# Write your bonus challenge code here
# Challenge 1: Male vs female average age

# Challenge 2: Passengers per class

# Challenge 3: Survival rate per class
