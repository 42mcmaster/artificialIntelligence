# %% [markdown]
# # ai01 DIY Task: Research & Analyze AI in Your Life
# ## Independent Research Project
#
# **Student Name:** ________________
# **Date:** ________________
# **Due Date:** ________________
#
# ---
#
# ## Project Overview
#
# In this independent task, you'll research and analyze 3 AI applications that **you use in your daily life**. This could be anything from social media recommendations to video games to fitness apps.
#
# **Your Goal:** Demonstrate deep understanding of how AI works by analyzing real-world applications you actually encounter.
#
# ---
#
# ## Instructions
#
# 1. **Identify 3 AI applications** you use regularly (not apps your parents use—apps YOU use)
# 2. **Research each one** using the internet, app documentation, or company blogs
# 3. **Analyze each application** using the framework below
# 4. **Create a summary** showing your understanding
#
# **Due:** Submit as a completed Jupyter notebook with all cells filled in

# %% [markdown]
# ---
#
# ## AI Application #1
#
# ### Name of Application: _______________________________________________
#
# **Examples:** TikTok, Instagram, Snapchat, Spotify, YouTube, Discord, Your Phone's Camera, Gaming Console AI, Fitness App, etc.
#
# ---
#
# ### Section 1: What AI Does It Use?
#
# **Question:** What task does the AI handle in this application?
#
# *(Example: "YouTube AI recommends videos I might want to watch")*
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 2: How Does It Work? (Your Understanding)
#
# **Question:** Based on what you learned, explain HOW the AI accomplishes this task. What data does it use? What patterns does it learn?
#
# *(Example: "YouTube learns what videos I watch, how long I watch them, and what videos people like me watch. It recognizes patterns and recommends similar videos.")*
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 3: What Type of AI Is It?
#
# **Is this Classification, Regression, Neural Network, or something else?**
#
# _______________________________________________________________________________
#
# **Why did you choose this?**
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 4: What Data Does It Need?
#
# **Question:** What training data or user data does this AI need to work?
#
# *(Example: "YouTube needs data about what I watch, how long I watch, what I like/dislike, and what people similar to me watch.")*
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 5: Would Traditional Programming Work?
#
# **Question:** Could a programmer hard-code this using traditional programming (if/else rules)? Why or why not?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 6: How Has It Improved Your Experience?
#
# **Question:** How does this AI make the app better for you personally? Give a specific example.
#
# *(Example: "TikTok's AI shows me videos about skateboarding, which I'm interested in. Without AI, I'd waste time scrolling through videos I don't care about.")*
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ---
#
# ## AI Application #2
#
# ### Name of Application: _______________________________________________
#
# ---
#
# ### Section 1: What AI Does It Use?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 2: How Does It Work? (Your Understanding)
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 3: What Type of AI Is It?
#
# _______________________________________________________________________________
#
# **Why?**
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 4: What Data Does It Need?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 5: Would Traditional Programming Work?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 6: How Has It Improved Your Experience?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ---
#
# ## AI Application #3
#
# ### Name of Application: _______________________________________________
#
# ---
#
# ### Section 1: What AI Does It Use?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 2: How Does It Work? (Your Understanding)
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 3: What Type of AI Is It?
#
# _______________________________________________________________________________
#
# **Why?**
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 4: What Data Does It Need?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 5: Would Traditional Programming Work?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Section 6: How Has It Improved Your Experience?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ---
#
# ## Final Reflection
#
# ### Question 1: What surprised you most about AI in your daily life?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Question 2: Do you think these apps should use AI, or would traditional programming be fine?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Question 3: What concerns, if any, do you have about AI in these apps?
#
# *(Example: Privacy, bias, addiction, environmental impact, etc.)*
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Question 4: If you could design an AI for an app YOU use, what would it do?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ---
#
# ## Research Sources
#
# List any websites, articles, or resources you used to research these AI applications:
#
# **Source 1:** ___________________________________________________________________
#
# **Source 2:** ___________________________________________________________________
#
# **Source 3:** ___________________________________________________________________
#
# ---
#
# ## Submission Checklist
#
# Before submitting, make sure you:
#
# - [ ] Identified 3 AI apps you actually use
# - [ ] Completed all sections for each application
# - [ ] Explained your reasoning (not just one-word answers)
# - [ ] Correctly identified the type of AI (Classification, Regression, Neural Network)
# - [ ] Answered all reflection questions
# - [ ] Listed your research sources
# - [ ] Saved and submitted the notebook
#
# ---
#
# **Great job exploring AI in your daily life! This shows you truly understand how AI works in the real world.**
