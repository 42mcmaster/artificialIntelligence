# %% [markdown]
# # ai01a Task: Identifying AI vs. Non-AI
# ## Traditional Programming vs. Machine Learning
#
# **Student Name:** ________________
# **Date:** ________________
#
# ---
#
# ## Task 1: Identify AI vs. Non-AI (Conceptual)
#
# For each scenario below, decide:
# - **Is this AI (machine learning) or traditional programming (hard-coded rules)?**
# - **Why?** Explain your reasoning.
#
# ### Scenario 1: YouTube Recommendations
#
# YouTube shows you video recommendations based on:
# - Videos you've watched before
# - Videos people similar to you have watched
# - How long you watched each video
#
# **Your answer:** Is this AI or traditional programming?
#
# _______________________________________________________________________________
#
# **Why?** (Explain your reasoning)
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Scenario 2: Age Verification on Websites
#
# A website has a rule:
# ```
# IF (age >= 18) {
#     allow access
# } ELSE {
#     deny access
# }
# ```
#
# **Your answer:** Is this AI or traditional programming?
#
# _______________________________________________________________________________
#
# **Why?**
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Scenario 3: Facial Recognition on Your Phone
#
# Your phone unlocks when it recognizes your face. The system:
# - Was trained on millions of different faces
# - Learned patterns of facial features
# - Recognizes new faces it's never seen before
#
# **Your answer:** Is this AI or traditional programming?
#
# _______________________________________________________________________________
#
# **Why?**
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Scenario 4: ATM Check Deposit
#
# An ATM reads the amount on a check using:
# - Fixed, hard-coded rules to find the numbers
# - Rules the programmer wrote to recognize specific font/patterns
# - Same logic every time (no learning from new checks)
#
# **Your answer:** Is this AI or traditional programming?
#
# _______________________________________________________________________________
#
# **Why?**
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Scenario 5: Chatbot That Learns
#
# A chatbot:
# - Was trained on thousands of real conversations
# - Learned patterns of how people communicate
# - Predicts the next word based on what came before
# - Improves as more conversations are added to training data
#
# **Your answer:** Is this AI or traditional programming?
#
# _______________________________________________________________________________
#
# **Why?**
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ---
#
# ## Task 2: Write a Simple Rule-Based Program
#
# ### Challenge: Temperature-Based Clothing Recommendation
#
# Write a Python function that recommends what to wear based on temperature. This is **traditional programming** (hard-coded rules), NOT AI.
#
# **Requirements:**
# - Input: Temperature in Fahrenheit
# - Output: Clothing recommendation
# - Use if/elif/else statements
# - Include at least 4 different temperature ranges
#
# **Temperature Guide:**
# - 90°F+ → Very hot (shorts, t-shirt, sunscreen)
# - 70-89°F → Warm (shorts or light pants, t-shirt)
# - 50-69°F → Cool (pants, light jacket)
# - Below 50°F → Cold (heavy jacket, long pants, hat, gloves)
#
# **Your code:**

# %%
# Your code here
# Write a function that recommends clothing based on temperature

def recommendClothing(temperatureFahrenheit):
    """
    Input: Temperature in Fahrenheit (number)
    Output: Clothing recommendation (string)
    
    This is traditional programming (hard-coded rules), not AI.
    """
    
    # Your code here
    # Use if/elif/else statements
    # Remember: This is NOT learning from data—you're writing the rules!
    
    pass  # Remove this when you write your code

# Test your function with different temperatures
# Example:
# print(recommendClothing(95))
# print(recommendClothing(60))
# print(recommendClothing(30))

# %% [markdown]
# ### Test Your Function
#
# Test your function with at least 4 different temperatures (one in each temperature range):

# %%
# Test your recommendClothing function here
# Your code here

# Test at least these temperatures:
# - 95°F (very hot)
# - 75°F (warm)
# - 60°F (cool)
# - 30°F (very cold)

print("Temperature Recommendations:")
print("="*50)

# %% [markdown]
# ---
#
# ## Task 3: Reflect on Your Code
#
# ### Question 1: Is Your Function AI?
#
# Is your `recommendClothing()` function machine learning / AI? Why or why not?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Question 2: What Would Make It AI?
#
# What would need to change for your clothing recommendation to be AI (machine learning) instead of traditional programming?
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ### Question 3: Limitations of Your Rule-Based Function
#
# What are some limitations of a hard-coded rule-based system for clothing recommendations?
#
# **Hint:** Think about factors besides temperature (humidity, activity level, personal preference, etc.)
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________
#
# _______________________________________________________________________________

# %% [markdown]
# ---
#
# ## Summary
#
# **What you've learned in this task:**
#
# 1. ✅ How to identify whether a system uses AI or traditional programming
# 2. ✅ How to write hard-coded rule-based logic in Python
# 3. ✅ Why rule-based systems have limitations (they don't learn or adapt)
# 4. ✅ The difference between "telling the computer what to do" and "letting it learn from data"
#
# **In the next task, you'll explore:**
# - Regression vs. Classification
# - Real-world examples of different ML approaches
# - When to use each type of AI
